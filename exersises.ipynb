# %%
import numpy as np

# %% [markdown]
# **Valid Sudoku**

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],

    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],

    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %% [markdown]
# **General Questions**

# %%
# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
#Get the shape of the matrix.
data.shape
# Out:
# (5, 3)

# %%
#Find the average age of students.
data[:,0].mean()
# Out:
# np.float64(18.4)

# %%
#Extract Math marks of all students.
data[:,1]
# Out:
# array([85, 92, 76, 65, 90])

# %%
#Find the highest Science mark.
data[:,2].max()
# Out:
# np.int64(95)

# %%
#Get details of the student who scored more than 90 in Math.
for i in data:
  if i[1] > 90:
    print(i)
# Out:
# [19 92 88]

# %%
#Increase Math marks of all students by 5.
data1 = data.copy()
data1 = data1[:,1] + 5
data1
# Out:
# array([90, 97, 81, 70, 95])

# %%
#Find how many students are younger than 19.
data[data[:,0] < 19].shape[0]
# Out:
# 3

# %%
#Calculate the average marks in each subject (column-wise mean).
print(f"Mean of math {data[1:, 1].mean()}")
print(f"Mean of Science {data[1:, 2].mean()}")
# Out:
# Mean of math 80.75
# Mean of Science 84.5

# %%
#Get data of students who scored at least 80 in both subjects.
for i in data:
  if i[1] >= 80 and i[2] >= 80:
    print(i)
# Out:
# [19 92 88]
# [20 90 85]

# %%
#Replace all Science marks < 75 with 0.
data2 = data.copy()
data2[data2[:,2] < 75, 3] = 0
data2
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18,  0, 70],
#        [20, 90, 85]])
